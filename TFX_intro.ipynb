# %% [markdown]
# <a href="https://colab.research.google.com/github/soerenml/tfx/blob/main/TFX_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML Ops with TFX
#
# Before we are going to start with our main code we should define MLops and why MLops is so important. Hapke and Nelson (2020) compare MLops to Ford's invention of scaleable production: decompose a products production into several scaleable steps.
#
# In 2020, ML is stil often done adhoc via notebooks lacking lineage and classical software engineering rigour. Different authors have stressed the point that Machine learning engineering is different from classical software engineering due to the fact that data (i.e. the environment) is under constant flux.
#
# The following notebook is based on Hapke and Nelson (2020) paraphrasing their findings and applying their code samples to my own problem.
#
# ## Why MLops?
#
# According to Hapke and Nelson (2020), MLops is needed to:
#
# + standardize and encapsulate processes,
# + save costs,
# + prevent bugs,
# + save costs,
# + focus on innovation not maintanance,
# + be GDPR compliant.
#
# All this is achieved through **automation**. The end goal is to have an automated machine with perfect lineage. In order to achieve this, Hapke and Nelson (2020) define ten distinct steps in a machine learning pipeline:
#
# ### 1. Data ingestion
# Data ingestion does not intend to conduct any processing on the incoming data. It's simply focssing on pure ingestion. Nevertheless, this process can become quite sophisticated depending on the type(batch / stream) and size of the data.

# %%
# !pip install tfx
# Out:
# Requirement already satisfied: tfx in /usr/local/lib/python3.6/dist-packages (0.25.0)
# Requirement already satisfied: pyarrow<0.18,>=0.17 in /usr/local/lib/python3.6/dist-packages (from tfx) (0.17.1)
# Requirement already satisfied: protobuf<4,>=3.12.2 in /usr/local/lib/python3.6/dist-packages (from tfx) (3.12.4)
# Requirement already satisfied: ml-metadata<0.26,>=0.25 in /usr/local/lib/python3.6/dist-packages (from tfx) (0.25.1)
# Requirement already satisfied: absl-py<0.11,>=0.9 in /usr/local/lib/python3.6/dist-packages (from tfx) (0.10.0)
# Requirement already satisfied: six<2,>=1.10 in /usr/local/lib/python3.6/dist-packages (from tfx) (1.15.0)
# Requirement already satisfied: tensorflow-data-validation<0.26,>=0.25 in /usr/local/lib/python3.6/dist-packages (from tfx) (0.25.0)
# Requirement already satisfied: attrs<21,>=19.3.0 in /usr/local/lib/python3.6/dist-packages (from tfx) (20.3.0)
# Requirement already satisfied: kubernetes<12,>=10.0.1 in /usr/local/lib/python3.6/dist-packages (from tfx) (11.0.0)
# Requirement already satisfied: pyyaml<6,>=3.12 in /usr/local/lib/python3.6/dist-packages (from tfx) (3.13)
# Requirement already satisfied: tensorflow-model-analysis<0.26,>=0.25 in /usr/local/lib/python3.6/dist-packages (from tfx) (0.25.0)
# Requirement already satisfied: tensorflow-serving-api!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15 in /usr/local/lib/python3.6/dist-packages (from tfx) (2.3.0)
# Requirement already satisfied: tensorflow-cloud<0.2,>=0.1 in /usr/local/lib/python3.6/dist-packages (from tfx) (0.1.10)
# Requirement already satisfied: google-api-python-client<2,>=1.7.8 in /usr/local/lib/python3.6/dist-packages (from tfx) (1.7.12)
# Requirement already satisfied: click<8,>=7 in /usr/local/lib/python3.6/dist-packages (from tfx) (7.1.2)
# Requirement already satisfied: apache-beam[gcp]<3,>=2.25 in /usr/local/lib/python3.6/dist-packages (from tfx) (2.26.0)
# Requirement already satisfied: tfx-bsl<0.26,>=0.25 in /usr/local/lib/python3.6/dist-packages (from tfx) (0.25.0)
# Requirement already satisfied: tensorflow-hub<0.10,>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from tfx) (0.9.0)
# Requirement already satisfied: keras-tuner<2,>=1 in /usr/local/lib/python3.6/dist-packages (from tfx) (1.0.2)
# Requirement already satisfied: tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2 in /usr/local/lib/python3.6/dist-packages (from tfx) (2.3.0)
# Requirement already satisfied: jinja2<3,>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from tfx) (2.11.2)
# Requirement already satisfied: grpcio<2,>=1.28.1 in /usr/local/lib/python3.6/dist-packages (from tfx) (1.34.0)
# Requirement already satisfied: docker<5,>=4.1 in /usr/local/lib/python3.6/dist-packages (from tfx) (4.4.0)
# Requirement already satisfied: tensorflow-transform<0.26,>=0.25 in /usr/local/lib/python3.6/dist-packages (from tfx) (0.25.0)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from pyarrow<0.18,>=0.17->tfx) (1.18.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<4,>=3.12.2->tfx) (50.3.2)
# Requirement already satisfied: joblib<0.15,>=0.12 in /usr/local/lib/python3.6/dist-packages (from tensorflow-data-validation<0.26,>=0.25->tfx) (0.14.1)
# Requirement already satisfied: pandas<2,>=1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-data-validation<0.26,>=0.25->tfx) (1.1.5)
# Requirement already satisfied: tensorflow-metadata<0.26,>=0.25 in /usr/local/lib/python3.6/dist-packages (from tensorflow-data-validation<0.26,>=0.25->tfx) (0.25.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.6/dist-packages (from kubernetes<12,>=10.0.1->tfx) (2.8.1)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.6/dist-packages (from kubernetes<12,>=10.0.1->tfx) (2020.12.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kubernetes<12,>=10.0.1->tfx) (2.25.0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from kubernetes<12,>=10.0.1->tfx) (1.17.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.6/dist-packages (from kubernetes<12,>=10.0.1->tfx) (0.57.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.6/dist-packages (from kubernetes<12,>=10.0.1->tfx) (1.3.0)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.6/dist-packages (from kubernetes<12,>=10.0.1->tfx) (1.24.3)
# Requirement already satisfied: ipywidgets<8,>=7 in /usr/local/lib/python3.6/dist-packages (from tensorflow-model-analysis<0.26,>=0.25->tfx) (7.5.1)
# Requirement already satisfied: ipython<8,>=7 in /usr/local/lib/python3.6/dist-packages (from tensorflow-model-analysis<0.26,>=0.25->tfx) (7.16.1)
# Requirement already satisfied: scipy<2,>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-model-analysis<0.26,>=0.25->tfx) (1.4.1)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.6/dist-packages (from tensorflow-cloud<0.2,>=0.1->tfx) (1.18.1)
# Requirement already satisfied: tensorflow-datasets<3.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-cloud<0.2,>=0.1->tfx) (3.0.0)
# Requirement already satisfied: tensorboard>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-cloud<0.2,>=0.1->tfx) (2.3.0)
# Requirement already satisfied: httplib2<1dev,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client<2,>=1.7.8->tfx) (0.17.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client<2,>=1.7.8->tfx) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client<2,>=1.7.8->tfx) (0.0.4)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (2018.9)
# Requirement already satisfied: future<1.0.0,>=0.18.2 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (0.18.2)
# Requirement already satisfied: oauth2client<5,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (4.1.3)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.7)
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (2.0.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (3.11.2)
# Requirement already satisfied: typing-extensions<3.8.0,>=3.7.0 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (3.7.4.3)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (2.5.8)
# Requirement already satisfied: avro-python3!=1.9.2,<1.10.0,>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.9.2.1)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.3.0)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (0.3.1.1)
# Requirement already satisfied: fastavro<2,>=0.21.4 in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.2.1)
# Requirement already satisfied: grpcio-gcp<1,>=0.2.2; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (0.2.2)
# Requirement already satisfied: google-cloud-bigtable<2,>=0.31.1; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.6.1)
# Requirement already satisfied: google-cloud-build<3,>=2.0.0; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (2.0.0)
# Requirement already satisfied: google-cloud-language<2,>=1.3.0; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.3.0)
# Requirement already satisfied: google-cloud-vision<2,>=0.38.0; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.0.0)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (0.5.31)
# Requirement already satisfied: google-cloud-videointelligence<2,>=1.8.0; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.16.1)
# Requirement already satisfied: cachetools<5,>=3.1.0; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (4.1.1)
# Requirement already satisfied: google-cloud-datastore<2,>=1.7.1; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.8.0)
# Requirement already satisfied: google-cloud-spanner<2,>=1.13.0; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.19.1)
# Requirement already satisfied: google-cloud-bigquery<2,>=1.6.0; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.21.0)
# Requirement already satisfied: google-cloud-pubsub<2,>=0.39.0; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.7.0)
# Requirement already satisfied: google-cloud-dlp<2,>=0.12.0; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.0.0)
# Requirement already satisfied: google-cloud-core<2,>=0.28.1; extra == "gcp" in /usr/local/lib/python3.6/dist-packages (from apache-beam[gcp]<3,>=2.25->tfx) (1.0.3)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from keras-tuner<2,>=1->tfx) (0.4.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from keras-tuner<2,>=1->tfx) (0.8.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from keras-tuner<2,>=1->tfx) (0.22.2.post1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from keras-tuner<2,>=1->tfx) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from keras-tuner<2,>=1->tfx) (20.7)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.6/dist-packages (from keras-tuner<2,>=1->tfx) (3.1.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (0.2.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (2.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (3.3.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (0.3.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (0.36.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (1.1.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<3,>=1.15.2->tfx) (1.6.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2<3,>=2.7.3->tfx) (1.1.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-metadata<0.26,>=0.25->tensorflow-data-validation<0.26,>=0.25->tfx) (1.52.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kubernetes<12,>=10.0.1->tfx) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kubernetes<12,>=10.0.1->tfx) (2.10)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.0.1->kubernetes<12,>=10.0.1->tfx) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.0.1->kubernetes<12,>=10.0.1->tfx) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib->kubernetes<12,>=10.0.1->tfx) (3.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (4.3.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (4.10.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (5.0.8)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (3.5.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.6/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.6/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (3.0.8)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (4.4.2)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.6/dist-packages (from google-cloud-storage->tensorflow-cloud<0.2,>=0.1->tfx) (0.4.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets<3.1.0->tensorflow-cloud<0.2,>=0.1->tfx) (2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.3.0->tensorflow-cloud<0.2,>=0.1->tfx) (0.4.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.3.0->tensorflow-cloud<0.2,>=0.1->tfx) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.3.0->tensorflow-cloud<0.2,>=0.1->tfx) (1.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=2.3.0->tensorflow-cloud<0.2,>=0.1->tfx) (3.3.3)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]<3,>=2.25->tfx) (0.4.8)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python3.6/dist-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]<3,>=2.25->tfx) (5.5.1)
# Requirement already satisfied: docopt in /usr/local/lib/python3.6/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.25->tfx) (0.6.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.6/dist-packages (from pydot<2,>=1.2.0->apache-beam[gcp]<3,>=2.25->tfx) (2.4.7)
# Requirement already satisfied: grpc-google-iam-v1<0.13dev,>=0.12.3 in /usr/local/lib/python3.6/dist-packages (from google-cloud-bigtable<2,>=0.31.1; extra == "gcp"->apache-beam[gcp]<3,>=2.25->tfx) (0.12.3)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-bigtable<2,>=0.31.1; extra == "gcp"->apache-beam[gcp]<3,>=2.25->tfx) (1.16.0)
# Requirement already satisfied: libcst>=0.2.5 in /usr/local/lib/python3.6/dist-packages (from google-cloud-build<3,>=2.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.25->tfx) (0.3.15)
# Requirement already satisfied: proto-plus>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-build<3,>=2.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.25->tfx) (1.13.0)
# Requirement already satisfied: fasteners>=0.14 in /usr/local/lib/python3.6/dist-packages (from google-apitools<0.5.32,>=0.5.31; extra == "gcp"->apache-beam[gcp]<3,>=2.25->tfx) (0.15)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (5.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (2.6.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (4.7.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (5.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.6.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from jedi>=0.10->ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.7.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.2.5)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard>=2.3.0->tensorflow-cloud<0.2,>=0.1->tfx) (3.1.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from libcst>=0.2.5->google-cloud-build<3,>=2.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.25->tfx) (0.6.0)
# Requirement already satisfied: dataclasses>=0.6.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from libcst>=0.2.5->google-cloud-build<3,>=2.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.25->tfx) (0.8)
# Requirement already satisfied: monotonic>=0.1 in /usr/local/lib/python3.6/dist-packages (from fasteners>=0.14->google-apitools<0.5.32,>=0.5.31; extra == "gcp"->apache-beam[gcp]<3,>=2.25->tfx) (1.5)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (20.0.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (1.5.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.9.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard>=2.3.0->tensorflow-cloud<0.2,>=0.1->tfx) (3.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from typing-inspect>=0.4.0->libcst>=0.2.5->google-cloud-build<3,>=2.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.25->tfx) (0.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.6.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (1.4.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (3.2.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.26,>=0.25->tfx) (0.5.1)

# %%
import tensorflow as tf
import tfx

print("""
Package versions\n
Tensorflow: {tf}
TFX: {tfx}""".format(
    tf=tf.__version__,
    tfx=tf.__version__))
# Out:
# Package versions
#
# Tensorflow: 2.3.0
# TFX: 2.3.0

# %% [markdown]
# ## 0 Set up project infrastructure[link text](https://)

# %%
import os
import shutil

# Create folder for metadata
if not os.path.exists('./metadata'):
    os.makedirs('./metadata')
else:
  shutil.rmtree('./metadata')
  os.makedirs('./metadata')

# Create folder for metadata
if not os.path.exists('./data'):
    os.makedirs('./data')
else:
  shutil.rmtree('./data')
  os.makedirs('./data')

# %%
# %%bash
# cd data
# wget 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
# Out:
# --2020-12-13 20:15:53--  https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘titanic.csv’
#
#      0K .......... .......... .......... .......... .......... 84% 6.85M 0s
#     50K ........                                              100% 10.8M=0.008s
#
# 2020-12-13 20:15:53 (7.25 MB/s) - ‘titanic.csv’ saved [60302/60302]

# %% [markdown]
# # 2. Define metadata
#
# There are different options to save metadata with TFX:
#
# + In-memory,
# + SQLite
# + MySQL
#
# In this notebook I am going use <code>interactive pipelines</code>

# %%
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext
context = InteractiveContext(
    pipeline_name = '',
    pipeline_root = './Metadata')
# Out:
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at ./Metadata/metadata.sqlite.

# %%
from tfx.components import CsvExampleGen
from tfx.utils.dsl_utils import external_input

examples = external_input("./data")
example_gen = CsvExampleGen(input=examples)
context.run(example_gen)
# Out:
# WARNING:absl:The "input" argument to the CsvExampleGen component has been deprecated by "input_base". Please update your usage as support for this argument will be removed soon.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 3
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 3
#         type_id: 5
#         uri: "./Metadata/CsvExampleGen/examples/3"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:single_split,num_files:1,total_bytes:60302,xor_checksum:1607890553,sum_checksum:1607890553"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             string_value: "0"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 5
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#         ))
